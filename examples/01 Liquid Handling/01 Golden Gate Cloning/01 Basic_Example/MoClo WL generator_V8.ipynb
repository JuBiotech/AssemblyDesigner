# %%
import seaborn as sns

from assembly_designer.workflow.workflow import LiquidHandlingWorkflow
from assembly_designer.manager.manager import AssemblyWorkflowManager
from assembly_designer.mtp_manager.mtp_manager import MTPManager
from assembly_designer.utils import find_planning_file

import logging
logging.basicConfig(level=logging.INFO)

# %%
type_of_molbioworks = ["PCR", "Golden Gate", "Gibson"]

# %%
# Meta data

type_of_molbiowork="Golden Gate"
try:
    file = find_planning_file(r".", "assembly")
except:
    file = "Automated_assembly_designer_V01.xlsx"

sheet_name="Plan+"
# Out:
# 11:28:22 INFO assembly_designer.utils.utils: Found planning file: C:\Users\domin\Documents\Git_Projekte\assembly_designer\examples\01 Liquid Handling\01 Golden Gate Cloning\01 Basic_Example\Automated_assembly_designer_V01_.xlsx

# %%
# Initialize with Golden Gate template
mtp_manager = MTPManager(default_template=type_of_molbiowork)

# List MTPs for Golden Gate
print("Template MTPs:", mtp_manager.list_mtps())

# # Access a specific MTP
# mtp = mtp_manager.get_mtp("mtp_source")

# # Switch to PCR template
# mtp_manager.switch_template("Golden Gate")
# print("PCR template MTPs:", mtp_manager.list_mtps())
# Out:
# Template MTPs: ['mtp_source', 'mtp_destination', 'master_mix', 'mtp_mastermix', 'mtp_dna_stocks', 'water']

# %%
# Initialize Workflow

# This cell defines the liquid handling workflow steps for MoClo assembly.
# Each workflow.add_step() call corresponds to a worklist file that will be generated.
#
# KEY PARAMETERS EXPLAINED:
# - sample_handling: "transfer" (move samples to specific wells) or "sample_distribution" (distribute to multiple wells)
# - start: "Yes" (first operation on this plate, initializes volumes) or "No" (subsequent operation)
# - additional_liquid_factor: Multiplier for extra volume (e.g., 1.1 = 10% extra for pipetting safety)
# - fake_source_plate: For simulation when source isn't a real plate


# ADJUST THIS WORKFLOW BASED ON YOUR EXCEL PLANNING FILE
# - Uncomment/comment steps based on parts in your assembly (e.g., if no Signal Peptide, keep it commented)
workflow = LiquidHandlingWorkflow()

workflow.add_step(
    process_label="Worklist_W",
    source_plate="water",
    destination_plate="mtp_source", # look @mtp_manager.list_mtps() which plate names there are: :)
    liquid_handling="Water to dilute",
    sample_handling="transfer",
    start = "Yes", #"Yes"/"No" --> important for filling volumes in the simulation. Yes if in that plate the first liquid handling operation appear with that worklist
    additional_liquid_factor = 1.1,
)
workflow.add_step(
    process_label="Worklist_DNA",
    source_plate="mtp_dna_stocks",
    destination_plate="mtp_source",
    liquid_handling="DNA parts for dilution",
    sample_handling="transfer",
    start = "Yes",
    additional_liquid_factor = 1.1,
)
workflow.add_step(
    process_label="Worklist_PM_parts",
    source_plate="mtp_source",
    destination_plate="mtp_source",
    liquid_handling="mix parts from Plamidmix",
    sample_handling="transfer",
    start = "No",
    additional_liquid_factor = 1.1,
)
workflow.add_step(
    process_label="Worklist_MM",
    source_plate="mtp_mastermix",
    destination_plate="mtp_destination",
    liquid_handling="Mastermix",
    sample_handling="sample_distribution",
    fake_source_plate="master_mix",
    start = "Yes",
    additional_liquid_factor = 1.1
)
# workflow.add_step(
#     process_label="Worklist_BB",
#     source_plate="mtp_source",
#     destination_plate="mtp_destination",
#     liquid_handling="Backbone",
#     sample_handling="transfer",
#     start = "No",
#     additional_liquid_factor = 1.1,
# )
workflow.add_step(
    process_label="Worklist_P",
    source_plate="mtp_source",
    destination_plate="mtp_destination",
    liquid_handling="Promotor",
    sample_handling="transfer",
    start = "No",
    additional_liquid_factor = 1.1
)
workflow.add_step(
    process_label="Worklist_RBS",
    source_plate="mtp_source",
    destination_plate="mtp_destination",
    liquid_handling="RBS",
    sample_handling="transfer",
    start = "No",
    additional_liquid_factor = 1.1
)
# workflow.add_step(
#     process_label="Worklist_SP",
#     source_plate="mtp_source",
#     destination_plate="mtp_destination",
#     liquid_handling="Signal Peptide",
#     sample_handling="transfer",
#     start = "No",
#     additional_liquid_factor = 1.1
# )
workflow.add_step(
    process_label="Worklist_GoI",
    source_plate="mtp_source",
    destination_plate="mtp_destination",
    liquid_handling="Gene of interest",
    sample_handling="transfer",
    start = "No",
    additional_liquid_factor = 1.1
)
# workflow.add_step(
#     process_label="Worklist_Tags",
#     source_plate="mtp_source",
#     destination_plate="mtp_destination",
#     liquid_handling="tags",
#     sample_handling="transfer",
#     start = "No",
#     additional_liquid_factor = 1.1,
# )
workflow.add_step(
    process_label="Worklist_PM",
    source_plate="mtp_source",
    destination_plate="mtp_destination",
    liquid_handling="Plasmidmix",
    sample_handling="sample_distribution",
    fake_source_plate="master_mix",
    start = "No",
    additional_liquid_factor = 1.1
)
workflow.add_step(
    process_label="Worklist_GG_water",
    source_plate="water",
    destination_plate="mtp_destination",
    liquid_handling="water to fill up final volume",
    sample_handling="transfer",
    start = "Yes",
    additional_liquid_factor = 1.1,
)
# Out:
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_W
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_DNA
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_PM_parts
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_MM
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_P
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_RBS
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_GoI
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_PM
# 11:28:22 INFO assembly_designer.workflow.workflow: Added step: Worklist_GG_water

# %%
workflow.generate_flowchart(
    save_path="workflow.png",
    export_format="png",
    fig_size=(22.0, 13.0),
    dpi=300,
    font_family="DejaVu Sans",
    node_font_size=20,
    edge_font_size=15,
    title="Liquid Handling Workflow",
    title_font_size=24,
    box_width=4.5,
    box_height=1.8,
    node_facecolor="#CFE2F3",
    node_edgecolor="black",
    node_linewidth=1.5,
    edge_color="black",
    edge_width=1.6,
    arrow_size=22,
    color_by_plate_type=True,
    plate_colors=None,
    label_box_alpha=0.95,
    show_axes=False,
    transparent=False,
    pad_inches=0.4,
    show_plot=True,
    max_labels_per_edge=None,
    spring_k=2.2,
    spring_iterations=400,
    spring_seed=42,
    scale=12.0,
)
# Out:
# 11:28:22 INFO assembly_designer.workflow.workflow: Flowchart saved to results\workflow.png

# %%
# Create AssemblyWorkflowManager
assembly_manager = AssemblyWorkflowManager()

# %%
# Initialize Workflow Manager
assembly_manager.initialize(plot=False, 
                            plot_information=False,
                            file_path=file,
                            mtp_manager=mtp_manager,
                            workflow=workflow,
                            sheet_name=sheet_name,
                            type_of_molbiowork=type_of_molbiowork)
# Out:
# 11:28:22 INFO assembly_designer.manager.manager: Initializing AssemblyWorkflowManager...
# C:\Users\domin\Documents\Git_Projekte\assembly_designer\assembly_designer\manager\manager.py:431: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   norm = sheet_df.applymap(lambda x: str(x).strip().lower() if pd.notna(x) else "")
# c:\Users\domin\miniforge3\envs\adesigner\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# C:\Users\domin\Documents\Git_Projekte\assembly_designer\assembly_designer\manager\manager.py:2566: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(
# c:\Users\domin\miniforge3\envs\adesigner\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# 11:28:23 INFO assembly_designer.manager.manager: All parts matched correctly.
# 11:28:23 INFO assembly_designer.manager.manager: Found 12 matching sheet(s): ['Worklist_W', 'Worklist_DNA', 'Worklist_PM_parts', 'Worklist_PM', 'Worklist_MM', 'Worklist_P', 'Worklist_BB', 'Worklist_SP', 'Worklist_RBS', 'Worklist_GoI', 'Worklist_Tags', 'Worklist_GG_water']
# 11:28:23 INFO assembly_designer.manager.manager: Found 12 worklist sheet(s): ['Worklist_W', 'Worklist_DNA', 'Worklist_PM_parts', 'Worklist_PM', 'Worklist_MM', 'Worklist_P', 'Worklist_BB', 'Worklist_SP', 'Worklist_RBS', 'Worklist_GoI', 'Worklist_Tags', 'Worklist_GG_water']
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_W.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_DNA.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_PM_parts.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_PM.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_MM.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_P.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_BB.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_SP.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_RBS.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_GoI.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_Tags.gwl
# 11:28:23 INFO assembly_designer.manager.manager: Created GWL file: Worklist_GG_water.gwl
# 11:28:23 INFO assembly_designer.manager.manager: All .gwl files were successfully created.
# 11:28:23 INFO assembly_designer.manager.manager: Created empty .gwl files for 12 sheet(s).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_W' (7 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_DNA' (7 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_PM_parts' (3 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_PM' (4 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_MM' (4 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_P' (4 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_BB' (0 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_SP' (0 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_RBS' (4 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_GoI' (4 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_Tags' (0 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded sheet 'Worklist_GG_water' (4 rows, 4 cols).
# 11:28:23 INFO assembly_designer.manager.manager: Loaded 12 worklist table(s).
# 11:28:23 INFO assembly_designer.manager.manager: Simulating volumes...
# 11:28:23 INFO assembly_designer.manager.manager: Initializing 158.9 µL in mtp_dna_stocks for 7 wells.
# 11:28:23 INFO assembly_designer.manager.manager: Initializing 30.9 µL in mtp_mastermix for 1 wells.
# 11:28:23 INFO assembly_designer.manager.manager: Initializing 782.9 µL in water for 1 wells.
# 11:28:23 INFO assembly_designer.manager.manager: Simulation complete.
# 11:28:23 INFO assembly_designer.manager.manager: Initialization complete.

# %%
from assembly_designer.utils import calculate_gg_mastermix_components

# %%
df=calculate_gg_mastermix_components(t4_concentration=500, 
                                                rest_enzyme_concentration=20, 
                                                t4_units=100, 
                                                rest_enzyme_units=10, 
                                                mastermix_volume=assembly_manager.sum_mastermix_volume, 
                                                volume_per_reaction=assembly_manager.volume_per_reaction, 
                                                bsa_100x=False)

# %%
assembly_manager.df_volumes
# Out:
#             Plate   Component  Total Volume (µL) Wells
# 0  mtp_dna_stocks      DVK_AE              10.00   E01
# 1  mtp_dna_stocks        PH36              27.10   A02
# 2  mtp_dna_stocks        Psyn              29.36   A01
# 3  mtp_dna_stocks         RBS              19.20   B01
# 4  mtp_dna_stocks       TrrnB              35.79   D01
# 5  mtp_dna_stocks        aroC              16.08   C02
# 6  mtp_dna_stocks  aroF_S188C              21.39   C01
# 7   mtp_mastermix  Mastermix1              30.88   A01
# 8           water       water             782.87   A01

# %%
# Process Workflow
assembly_manager.process_workflow(plot=False)
# Out:
# 11:28:23 INFO assembly_designer.manager.manager: Processing workflow...
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_W' -> worklist\Worklist_W.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_DNA' -> worklist\Worklist_DNA.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_PM_parts' -> worklist\Worklist_PM_parts.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_PM' -> worklist\Worklist_PM.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_MM' -> worklist\Worklist_MM.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_P' -> worklist\Worklist_P.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_RBS' -> worklist\Worklist_RBS.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_GoI' -> worklist\Worklist_GoI.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported worklist 'Worklist_GG_water' -> worklist\Worklist_GG_water.csv
# 11:28:23 INFO assembly_designer.manager.manager: Exported master worklist with 41 rows -> worklist\Master_Worklist.csv
# 11:28:23 INFO assembly_designer.manager.manager: Worklist CSV export done: 9 individual file(s) -> worklist
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_W
# 11:28:23 INFO assembly_designer.manager.manager: Handling transfer.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_W' written to Worklist_W.gwl.
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_DNA
# 11:28:23 INFO assembly_designer.manager.manager: Handling transfer.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_DNA' written to Worklist_DNA.gwl.
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_PM_parts
# 11:28:23 INFO assembly_designer.manager.manager: Handling transfer.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_PM_parts' written to Worklist_PM_parts.gwl.
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_MM
# 11:28:23 INFO assembly_designer.manager.manager: Handling sample distribution.
# 11:28:23 INFO assembly_designer.utils.utils: Volume check summary: total=4, missing=0, low(<2.000 µL)=0 | Step=Worklist_MM
# 11:28:23 INFO assembly_designer.manager.manager: Distribute 4.0 µL of Mastermix1 from column1 to 4 destination wells.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_MM.gwl' created successfully.
# 11:28:23 INFO assembly_designer.manager.manager: generate_coordinates: done | n_values=7, offset=1, coords=[1, 2, 3, 4, 5, 9, 11]
# 11:28:23 INFO assembly_designer.manager.manager: Global coordinate mapping (may contain gaps): [1, 2, 3, 4, 5, 9, 11]
# 11:28:23 INFO assembly_designer.manager.manager: Assigned compact source coordinates (per-step): items=['Mastermix1'] -> coords=[1]
# 11:28:23 INFO assembly_designer.manager.manager: GWL modified (1 lines).
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_P
# 11:28:23 INFO assembly_designer.manager.manager: Handling transfer.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_P' written to Worklist_P.gwl.
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_RBS
# 11:28:23 INFO assembly_designer.manager.manager: Handling transfer.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_RBS' written to Worklist_RBS.gwl.
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_GoI
# 11:28:23 INFO assembly_designer.manager.manager: Handling transfer.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_GoI' written to Worklist_GoI.gwl.
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_PM
# 11:28:23 INFO assembly_designer.manager.manager: Handling sample distribution.
# 11:28:23 INFO assembly_designer.utils.utils: Volume check summary: total=4, missing=0, low(<2.000 µL)=0 | Step=Worklist_PM
# 11:28:23 INFO assembly_designer.manager.manager: Distribute 4.0 µL of Plasmidmix1 from column1 to 4 destination wells.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_PM.gwl' created successfully.
# 11:28:23 INFO assembly_designer.manager.manager: generate_coordinates: done | n_values=7, offset=1, coords=[1, 2, 3, 4, 5, 9, 11]
# 11:28:23 INFO assembly_designer.manager.manager: Global coordinate mapping (may contain gaps): [1, 2, 3, 4, 5, 9, 11]
# 11:28:23 INFO assembly_designer.manager.manager: Assigned compact source coordinates (per-step): items=['Plasmidmix1'] -> coords=[1]
# 11:28:23 INFO assembly_designer.manager.manager: GWL modified (1 lines).
# 11:28:23 INFO assembly_designer.manager.manager: Processing step: Worklist_GG_water
# 11:28:23 INFO assembly_designer.manager.manager: Handling transfer.
# 11:28:23 INFO assembly_designer.manager.manager: Worklist 'Worklist_GG_water' written to Worklist_GG_water.gwl.

# %%
# Plot Destination Plate Layout
assembly_manager.plot_destination_plate(save_path="results/Assembly_Plan.png", 
                                        highlight_column="Promotor",  
                                        max_lines=6,
                                        exclude_keywords=["water", "mastermix"],
                                        color_palette=sns.color_palette("Blues", n_colors=8),
                                        cmap = "tab10",)

# Display the saved image
assembly_manager.plot_destination_plate(save_path=None)
# Out:
# 11:28:23 INFO assembly_designer.manager.manager: Excluded columns: ['Mastermix', 'Water']
# 11:28:23 INFO assembly_designer.manager.manager: Plate plot saved to: results/Assembly_Plan.png
# 11:28:23 INFO assembly_designer.manager.manager: Destination plate plot saved to results/Assembly_Plan.png
# 11:28:24 INFO assembly_designer.manager.manager: Destination plate plot saved to None

# %%
##### Check that the "# Initialize Workflow" cell is correctly set up before running the simulation, as it defines the workflow steps that will be executed.
##### Improper setup can lead to errors or an inaccurate simulation.
##### Ensure that the steps in the workflow match the operations you intend to simulate, and that the source and destination plates are correctly specified.

# Simulate the complete liquid handling process
assembly_manager.simulate_liquid_handling(fps=0.5, delay_frames=1)
# Out:
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
#     table.fastprogress { border-collapse: collapse; margin: 1em 0; font-size: 0.9em; }
#     table.fastprogress th, table.fastprogress td { padding: 8px 12px; border: 1px solid #ddd; text-align: left; }
#     table.fastprogress thead tr { background: #f8f9fa; font-weight: bold; }
#     table.fastprogress tbody tr:nth-of-type(even) { background: #f8f9fa; }
# </style>
# <div><progress max="9" value="9"></progress> 100.00% [9/9 00:01&lt;00:00]</div>
# 11:28:25 INFO assembly_designer.manager.manager: Workflow simulation GIF written to results\Workflow_simulation.gif

# %%
# Simulate plate history for the "mtp_source" plate (DNA dilution and Plasmidmix preparation)
mtp_manager.simulate_plate_history(mtp_manager.get_mtp("mtp_source"), fps=0.5, delay_frames=1)
# Out:
# <div><progress max="7" value="7"></progress> 100.00% [7/7 00:01&lt;00:00]</div>
# 11:28:26 INFO assembly_designer.mtp_manager.mtp_manager: Plate history GIF written to results\mtp_source.gif

# %%
# Simulate plate history for the "mtp_destination" plate (final reaction assembly)
mtp_manager.simulate_plate_history(mtp_manager.get_mtp("mtp_destination"),fps=0.5, delay_frames=1)
# Out:
# <div><progress max="7" value="7"></progress> 100.00% [7/7 00:01&lt;00:00]</div>
# 11:28:28 INFO assembly_designer.mtp_manager.mtp_manager: Plate history GIF written to results\Destination_Plate_1.gif
